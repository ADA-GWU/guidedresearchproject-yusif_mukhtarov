# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('data/test/0026.jpg')
stddev =  127



noise = np.zeros(img.shape, np.uint8)
p = 0.1
noise = (np.random.normal(0, stddev, img.shape).astype(np.uint8)*p).astype(np.uint8)

fig=plt.figure(dpi=300)
fig.add_subplot(1,3,1)
plt.imshow(noise)
plt.axis("off")
plt.title(f'{int(p*100)}%')


noise = np.zeros(img.shape, np.uint8)
p = 0.5
noise = (np.random.normal(0, stddev, img.shape).astype(np.uint8)*p).astype(np.uint8)

fig.add_subplot(1,3,2)
plt.imshow(noise)
plt.axis("off")
plt.title(f'{int(p*100)}%')

noise = np.zeros(img.shape, np.uint8)
p = 1
noise = (np.random.normal(0, stddev, img.shape).astype(np.uint8)*p).astype(np.uint8)

fig.add_subplot(1,3,3)
plt.imshow(noise)
plt.axis("off")
plt.title(f'{int(p*100)}%')
# Out:
# Text(0.5, 1.0, '100%')

# %%
def adding_gauss_noise(path, mean, noise_percentage):
    img = cv2.imread(path)
    noise = np.zeros(img.shape, np.uint8)
    noise = (np.random.normal(0, 127, img.shape).astype(np.uint8)*noise_percentage).astype(np.uint8)
    noisy_img = cv2.add(img, noise)
    return noise, noisy_img

img =  cv2.imread('data/test/0026.jpg')
gauss_noise, noisy_img = adding_gauss_noise('data/test/0026.jpg', 0, 1)


fig=plt.figure(dpi=300)
fig.add_subplot(1,3,1)
plt.imshow(img)
plt.axis("off")
plt.title("Original")

fig.add_subplot(1,3,2)
plt.imshow(gauss_noise)
plt.axis("off")
plt.title("Gaussian Noise")

fig.add_subplot(1,3,3)
plt.imshow(noisy_img)
plt.axis("off")
plt.title("Combined")
# Out:
# Text(0.5, 1.0, 'Combined')
